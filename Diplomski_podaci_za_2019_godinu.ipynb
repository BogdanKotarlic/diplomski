# %%
import pandas as pd
import datetime
from datetime import time
import matplotlib.pyplot as plt

# %%
#2019. GODINA:

# %%
#UCITAVANJE PODATAKA
nez_opendata_2019 = pd.read_excel("nez-opendata-2019.xlsx")

# %%
#PRIKAZ TABELE
df_nez_opendata_2019 = pd.DataFrame(nez_opendata_2019)
df_nez_opendata_2019
df = df_nez_opendata_2019
df
# Out:
#             ID Policijska uprava   Opština     Datum i vreme  Geolokacija (X)  \
# 0      1241358           BEOGRAD  BARAJEVO  02.01.2019,04:30        20.303490
# 1      1241066           BEOGRAD  BARAJEVO  03.01.2019,09:15        20.416233
# 2      1241336           BEOGRAD  BARAJEVO  03.01.2019,09:00        20.395270
# 3      1241822           BEOGRAD  BARAJEVO  06.01.2019,17:20        20.300329
# 4      1243473           BEOGRAD  BARAJEVO  06.01.2019,10:50        20.374640
# ...        ...               ...       ...               ...              ...
# 35951  1276739             ŠABAC     ŠABAC  30.12.2019,19:05        19.704569
# 35952  1277382             ŠABAC     ŠABAC  30.12.2019,10:30        19.701728
# 35953  1276804             ŠABAC     ŠABAC  31.12.2019,10:00        19.684956
# 35954  1276911             ŠABAC     ŠABAC  31.12.2019,21:10        19.369528
# 35955  1276823             ŠABAC     ŠABAC  31.12.2019,14:00        19.663654
#
# ...

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu je:")
count_ukupan_broj_u_srbiji = len(df)
print(count_ukupan_broj_u_srbiji)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu je:")
count_ukupan_broj_u_ns = len(df[df["Opština"]=="NOVI SAD"])
print(count_ukupan_broj_u_ns)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_poginulim = len(df[df["Vrsta"]=="Sa poginulim"])
print(count_ukupan_broj_u_srbiji_sa_poginulim)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_poginulim = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim')])
print(count_ukupan_broj_u_ns_sa_poginulim) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_povredama = len(df[df["Vrsta"]=="Sa povredjenim"])
print(count_ukupan_broj_u_srbiji_sa_povredama)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_povredama = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim')])
print(count_ukupan_broj_u_ns_sa_povredama) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_mat_stetom = len(df[df["Vrsta"]=="Sa mat.stetom"])
print(count_ukupan_broj_u_srbiji_sa_mat_stetom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_mat_stetom = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom')])
print(count_ukupan_broj_u_ns_sa_mat_stetom)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu je:
# 35956
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu je:
# 2364
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom za 2019. godinu je:
# 509
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom za 2019. godinu je:
# 21
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama za 2019. godinu je:
# 13800
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama za 2019. godinu je:
# 1127
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom za 2019. godinu je:
# 21647
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom za 2019. godinu je:
# 1216

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA PESACIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa pesacima je:")
count_ukupan_broj_u_srbiji_sa_pesacima = len(df[df['Tip']=="SN SA PEŠACIMA"])
print(count_ukupan_broj_u_srbiji_sa_pesacima)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA PESACIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa pesacima je:")
count_ukupan_broj_u_ns_sa_pesacima = len(df[(df["Opština"]=="NOVI SAD") & (df['Tip']=="SN SA PEŠACIMA")])
print(count_ukupan_broj_u_ns_sa_pesacima)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM SA PESACIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i pesacima za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_pesacima_sa_poginulim = len(df[(df["Vrsta"]=="Sa poginulim") & (df['Tip']=='SN SA PEŠACIMA')])
print(count_ukupan_broj_u_srbiji_sa_pesacima_sa_poginulim)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM SA PESACIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i pesacima za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_pesacima_sa_poginulim = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim') & (df['Tip']=='SN SA PEŠACIMA')])
print(count_ukupan_broj_u_ns_sa_pesacima_sa_poginulim) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA I PESACIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i pesacima za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_pesacima_sa_povredama = len(df[(df["Vrsta"]=="Sa povredjenim") & (df['Tip']=='SN SA PEŠACIMA')])
print(count_ukupan_broj_u_srbiji_sa_pesacima_sa_povredama)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA I PESACIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i pesacima za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_pesacima_sa_povredama = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim') & (df['Tip']=='SN SA PEŠACIMA')])
print(count_ukupan_broj_u_ns_sa_pesacima_sa_povredama) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM I PESACIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i pesacima za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_pesacima_sa_mat_stetom = len(df[(df["Vrsta"]=="Sa mat.stetom") & (df['Tip']=='SN SA PEŠACIMA')])
print(count_ukupan_broj_u_srbiji_sa_pesacima_sa_mat_stetom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM I PESACIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i pesacima za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_pesacima_sa_mat_stetom = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom') & (df['Tip']=='SN SA PEŠACIMA')])
print(count_ukupan_broj_u_ns_sa_pesacima_sa_mat_stetom)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa pesacima je:
# 2842
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa pesacima je:
# 204
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i pesacima za 2019. godinu je:
# 127
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i pesacima za 2019. godinu je:
# 8
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i pesacima za 2019. godinu je:
# 2669
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i pesacima za 2019. godinu je:
# 195
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i pesacima za 2019. godinu je:
# 46
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i pesacima za 2019. godinu je:
# 1

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa parkiranim vozilima je:")
count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom = len(df[df['Tip']=="SN SA PARKIRANIM VOZILIMA"])
print(count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa parkiranim vozilima je:")
count_ukupan_broj_u_ns_sa_parkiranim_vozilom = len(df[(df["Opština"]=="NOVI SAD") & (df['Tip']=="SN SA PARKIRANIM VOZILIMA")])
print(count_ukupan_broj_u_ns_sa_parkiranim_vozilom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM SA PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i parkiranim vozilima za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_poginulim = len(df[(df["Vrsta"]=="Sa poginulim") & (df['Tip']=='SN SA PARKIRANIM VOZILIMA')])
print(count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_poginulim)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM SA PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i parkiranim vozilima za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_poginulim = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim') & (df['Tip']=='SN SA PARKIRANIM VOZILIMA')])
print(count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_poginulim) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA I PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i parkiranim vozilima za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_povredama = len(df[(df["Vrsta"]=="Sa povredjenim") & (df['Tip']=='SN SA PARKIRANIM VOZILIMA')])
print(count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_povredama)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA I PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i parkiranim vozilima za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_povredama = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim') & (df['Tip']=='SN SA PARKIRANIM VOZILIMA')])
print(count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_povredama) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM I PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i parkiranim vozilima za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_mat_stetom = len(df[(df["Vrsta"]=="Sa mat.stetom") & (df['Tip']=='SN SA PARKIRANIM VOZILIMA')])
print(count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_mat_stetom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM I PARKIRANIM VOZILIMA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i parkiranim vozilima za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_mat_stetom = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom') & (df['Tip']=='SN SA PARKIRANIM VOZILIMA')])
print(count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_mat_stetom)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa parkiranim vozilima je:
# 5456
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa parkiranim vozilima je:
# 273
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i parkiranim vozilima za 2019. godinu je:
# 22
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i parkiranim vozilima za 2019. godinu je:
# 1
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i parkiranim vozilima za 2019. godinu je:
# 357
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i parkiranim vozilima za 2019. godinu je:
# 13
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i parkiranim vozilima za 2019. godinu je:
# 5077
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i parkiranim vozilima za 2019. godinu je:
# 259

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa jednim vozilom je:")
count_ukupan_broj_u_srbiji_sa_jednim_vozilom = len(df[df['Tip']=="SN SA JEDNIM VOZILOM"])
print(count_ukupan_broj_u_srbiji_sa_jednim_vozilom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa jednim vozilom je:")
count_ukupan_broj_u_ns_sa_jednim_vozilom = len(df[(df["Opština"]=="NOVI SAD") & (df['Tip']=="SN SA JEDNIM VOZILOM")])
print(count_ukupan_broj_u_ns_sa_jednim_vozilom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM SA JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i jednim vozilom za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_poginulim = len(df[(df["Vrsta"]=="Sa poginulim") & (df['Tip']=='SN SA JEDNIM VOZILOM')])
print(count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_poginulim)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM SA JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i jednim vozilom za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_poginulim = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim') & (df['Tip']=='SN SA JEDNIM VOZILOM')])
print(count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_poginulim) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA I JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i jednim vozilom za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_povredama = len(df[(df["Vrsta"]=="Sa povredjenim") & (df['Tip']=='SN SA JEDNIM VOZILOM')])
print(count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_povredama)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA I JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i jednim vozilom za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_povredama = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim') & (df['Tip']=='SN SA JEDNIM VOZILOM')])
print(count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_povredama) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM I JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i jednim vozilom za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_mat_stetom = len(df[(df["Vrsta"]=="Sa mat.stetom") & (df['Tip']=='SN SA JEDNIM VOZILOM')])
print(count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_mat_stetom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM I JEDNIM VOZILOM
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i jednim vozilom za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_mat_stetom = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom') & (df['Tip']=='SN SA JEDNIM VOZILOM')])
print(count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_mat_stetom)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa jednim vozilom je:
# 7555
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa jednim vozilom je:
# 381
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i jednim vozilom za 2019. godinu je:
# 165
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i jednim vozilom za 2019. godinu je:
# 1
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i jednim vozilom za 2019. godinu je:
# 2602
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i jednim vozilom za 2019. godinu je:
# 86
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i jednim vozilom za 2019. godinu je:
# 4788
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i jednim vozilom za 2019. godinu je:
# 294

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa dva ili vise vozila je:")
count_ukupan_broj_u_srbiji_sa_dva_vozila = len(df[df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA")])
print(count_ukupan_broj_u_srbiji_sa_dva_vozila)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa dva ili vise vozila je:")
count_ukupan_broj_u_ns_sa_dva_vozila = len(df[(df["Opština"]=="NOVI SAD") & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_ns_sa_dva_vozila)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM I DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i dva ili vise vozila za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_poginulim = len(df[(df["Vrsta"]=="Sa poginulim") & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_poginulim)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM I DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i dva ili vise vozila za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_dva_vozila_sa_poginulim = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim') & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_ns_sa_dva_vozila_sa_poginulim) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA I DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i dva ili vise vozila za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_povredama = len(df[(df["Vrsta"]=="Sa povredjenim") & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_povredama)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA I DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i dva ili vise vozila za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_dva_vozila_sa_povredama = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim') & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_ns_sa_dva_vozila_sa_povredama) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM I DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i dva ili vise vozila za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_mat_stetom = len(df[(df["Vrsta"]=="Sa mat.stetom") & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_mat_stetom)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM I DVA ILI VISE VOZILA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i dva ili vise vozila za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_dva_vozila_sa_mat_stetom = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom') & (df['Tip'].str.contains("SN SA NAJMANjE DVA VOZILA"))])
print(count_ukupan_broj_u_ns_sa_dva_vozila_sa_mat_stetom)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu sa dva ili vise vozila je:
# 20103
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu sa dva ili vise vozila je:
# 1506
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom i dva ili vise vozila za 2019. godinu je:
# 195
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom i dva ili vise vozila za 2019. godinu je:
# 11
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama i dva ili vise vozila za 2019. godinu je:
# 8172
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama i dva ili vise vozila za 2019. godinu je:
# 833
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom i dva ili vise vozila za 2019. godinu je:
# 11736
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom i dva ili vise vozila za 2019. godinu je:
# 662

# %%
#PRAVLJENJE ODGOVARAJUCEG FORMATA ZA DALJI RAD
df['Datum i vreme'] = df['Datum i vreme'].str.replace(',', '-', regex=True)
df['Datum i vreme'] = df['Datum i vreme'].str.replace('.', '', regex=True)
df['Datum i vreme'] = df['Datum i vreme'].str.replace(':', '', regex=True)

df['Datum i vreme'] = pd.to_datetime(df['Datum i vreme'], format='%d%m%Y-%H%M')

# %%
df
# Out:
#             ID Policijska uprava   Opština       Datum i vreme  \
# 0      1241358           BEOGRAD  BARAJEVO 2019-01-02 04:30:00
# 1      1241066           BEOGRAD  BARAJEVO 2019-01-03 09:15:00
# 2      1241336           BEOGRAD  BARAJEVO 2019-01-03 09:00:00
# 3      1241822           BEOGRAD  BARAJEVO 2019-01-06 17:20:00
# 4      1243473           BEOGRAD  BARAJEVO 2019-01-06 10:50:00
# ...        ...               ...       ...                 ...
# 35951  1276739             ŠABAC     ŠABAC 2019-12-30 19:05:00
# 35952  1277382             ŠABAC     ŠABAC 2019-12-30 10:30:00
# 35953  1276804             ŠABAC     ŠABAC 2019-12-31 10:00:00
# 35954  1276911             ŠABAC     ŠABAC 2019-12-31 21:10:00
# 35955  1276823             ŠABAC     ŠABAC 2019-12-31 14:00:00
#
#        Geolokacija (X)  Geolokacija(Y)           Vrsta  \
# 0            20.303490       44.592670   Sa mat.stetom
# 1            20.416233       44.582363   Sa mat.stetom
# ...

# %%
#PRAVLJENJE KOLONE DAN U NEDELJI
df['Dan u nedelji'] = df['Datum i vreme'].dt.day_name()

# %%
df
# Out:
#             ID Policijska uprava   Opština       Datum i vreme  \
# 0      1241358           BEOGRAD  BARAJEVO 2019-01-02 04:30:00
# 1      1241066           BEOGRAD  BARAJEVO 2019-01-03 09:15:00
# 2      1241336           BEOGRAD  BARAJEVO 2019-01-03 09:00:00
# 3      1241822           BEOGRAD  BARAJEVO 2019-01-06 17:20:00
# 4      1243473           BEOGRAD  BARAJEVO 2019-01-06 10:50:00
# ...        ...               ...       ...                 ...
# 35951  1276739             ŠABAC     ŠABAC 2019-12-30 19:05:00
# 35952  1277382             ŠABAC     ŠABAC 2019-12-30 10:30:00
# 35953  1276804             ŠABAC     ŠABAC 2019-12-31 10:00:00
# 35954  1276911             ŠABAC     ŠABAC 2019-12-31 21:10:00
# 35955  1276823             ŠABAC     ŠABAC 2019-12-31 14:00:00
#
#        Geolokacija (X)  Geolokacija(Y)           Vrsta  \
# 0            20.303490       44.592670   Sa mat.stetom
# 1            20.416233       44.582363   Sa mat.stetom
# ...

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu za vikend je:")
count_ukupan_broj_u_srbiji_vikend = len(df[(df["Dan u nedelji"]=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_srbiji_vikend)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu za vikend je:")
count_ukupan_broj_u_ns_vikend = len(df[(df["Opština"]=="NOVI SAD") & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_ns_vikend)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom za vikend za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_poginulim_vikend = len(df[(df["Vrsta"]=="Sa poginulim") & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_srbiji_sa_poginulim_vikend)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom za vikend za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_poginulim_vikend = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim') & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_ns_sa_poginulim_vikend) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama za vikend za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_povredama_vikend = len(df[(df["Vrsta"]=="Sa povredjenim") & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_srbiji_sa_povredama_vikend)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama za vikend za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_povredama_vikend = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim') & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_ns_sa_povredama_vikend) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom za vikend za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_mat_stetom_vikend = len(df[(df["Vrsta"]=="Sa mat.stetom") & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_srbiji_sa_mat_stetom_vikend)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM ZA VIKEND
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom za vikend za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_mat_stetom_vikend = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom') & (df['Dan u nedelji']=="Saturday") | (df['Dan u nedelji']=="Sunday")])
print(count_ukupan_broj_u_ns_sa_mat_stetom_vikend)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu za vikend je:
# 9300
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu za vikend je:
# 4735
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom za vikend za 2019. godinu je:
# 4489
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom za vikend za 2019. godinu je:
# 4413
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama za vikend za 2019. godinu je:
# 6350
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama za vikend za 2019. godinu je:
# 4559
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom za vikend za 2019. godinu je:
# 7285
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom za vikend za 2019. godinu je:
# 4587

# %%
#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu tokom radnih dana je:")
count_ukupan_broj_u_srbiji_radni_dan = count_ukupan_broj_u_srbiji - count_ukupan_broj_u_srbiji_vikend 
print(count_ukupan_broj_u_srbiji_radni_dan)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu tokom radnih dana je:")
count_ukupan_broj_u_ns_radni_dan = count_ukupan_broj_u_ns_vikend - count_ukupan_broj_u_ns
print(count_ukupan_broj_u_ns_radni_dan)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom tokom radnih dana za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_poginulim_radni_dan = count_ukupan_broj_u_srbiji_sa_poginulim_vikend - count_ukupan_broj_u_srbiji_sa_poginulim
print(count_ukupan_broj_u_srbiji_sa_poginulim_radni_dan)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom tokom radnih dana za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_poginulim_radni_dan = count_ukupan_broj_u_ns_sa_poginulim_vikend - count_ukupan_broj_u_ns_sa_poginulim
print(count_ukupan_broj_u_ns_sa_poginulim_radni_dan) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama tokom radnih dana za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_povredama_radni_dan = count_ukupan_broj_u_srbiji_sa_povredama - count_ukupan_broj_u_srbiji_sa_povredama_vikend
print(count_ukupan_broj_u_srbiji_sa_povredama_radni_dan)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama tokom radnih dana za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_povredama_radni_dan = count_ukupan_broj_u_ns_sa_povredama_vikend - count_ukupan_broj_u_ns_sa_povredama
print(count_ukupan_broj_u_ns_sa_povredama_radni_dan) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom tokom radnih dana za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_mat_stetom_radni_dan = count_ukupan_broj_u_srbiji_sa_mat_stetom - count_ukupan_broj_u_srbiji_sa_mat_stetom_vikend
print(count_ukupan_broj_u_srbiji_sa_mat_stetom_radni_dan)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM TOKOM RADNIH DANA
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom tokom radnih dana za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_mat_stetom_radni_dan = count_ukupan_broj_u_ns_sa_mat_stetom_vikend - count_ukupan_broj_u_ns_sa_mat_stetom
print(count_ukupan_broj_u_ns_sa_mat_stetom_radni_dan)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu tokom radnih dana je:
# 26656
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu tokom radnih dana je:
# 2371
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom tokom radnih dana za 2019. godinu je:
# 3980
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom tokom radnih dana za 2019. godinu je:
# 4392
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama tokom radnih dana za 2019. godinu je:
# 7450
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama tokom radnih dana za 2019. godinu je:
# 3432
# Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom tokom radnih dana za 2019. godinu je:
# 14362
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom tokom radnih dana za 2019. godinu je:
# 3371

# %%
df['Vreme'] = pd.to_datetime(df['Datum i vreme'], format='%d%m%Y-%H%M').dt.time
df
# Out:
#             ID Policijska uprava   Opština       Datum i vreme  \
# 0      1241358           BEOGRAD  BARAJEVO 2019-01-02 04:30:00
# 1      1241066           BEOGRAD  BARAJEVO 2019-01-03 09:15:00
# 2      1241336           BEOGRAD  BARAJEVO 2019-01-03 09:00:00
# 3      1241822           BEOGRAD  BARAJEVO 2019-01-06 17:20:00
# 4      1243473           BEOGRAD  BARAJEVO 2019-01-06 10:50:00
# ...        ...               ...       ...                 ...
# 35951  1276739             ŠABAC     ŠABAC 2019-12-30 19:05:00
# 35952  1277382             ŠABAC     ŠABAC 2019-12-30 10:30:00
# 35953  1276804             ŠABAC     ŠABAC 2019-12-31 10:00:00
# 35954  1276911             ŠABAC     ŠABAC 2019-12-31 21:10:00
# 35955  1276823             ŠABAC     ŠABAC 2019-12-31 14:00:00
#
#        Geolokacija (X)  Geolokacija(Y)           Vrsta  \
# 0            20.303490       44.592670   Sa mat.stetom
# 1            20.416233       44.582363   Sa mat.stetom
# ...

# %%
pocetak_dana = datetime.time(5,0,1)
kraj_dana = datetime.time(22,0,0)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu preko dana je:")
count_ukupan_broj_u_srbiji_preko_dana = len(df[df["Vreme"].between(pocetak_dana, kraj_dana)])
print(count_ukupan_broj_u_srbiji_preko_dana)
print("Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu preko noci je:")
count_ukupan_broj_u_srbiji_preko_noci = count_ukupan_broj_u_srbiji - count_ukupan_broj_u_srbiji_preko_dana
print(count_ukupan_broj_u_srbiji_preko_noci)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu preko dana je:")
count_ukupan_broj_u_ns_preko_dana = len(df[(df["Opština"]=="NOVI SAD") & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_ns_preko_dana)
print("Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu preko noci je:")
count_ukupan_broj_u_ns_preko_noci = count_ukupan_broj_u_ns - count_ukupan_broj_u_ns_preko_dana
print(count_ukupan_broj_u_ns_preko_noci)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA SMRTNIM ISHODOM PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom preko dana za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_poginulim_preko_dana = len(df[(df["Vrsta"]=="Sa poginulim") & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_srbiji_sa_poginulim_preko_dana)
print("Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom preko noci za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_poginulim_preko_noci = count_ukupan_broj_u_srbiji_sa_poginulim - count_ukupan_broj_u_srbiji_sa_poginulim_preko_dana
print(count_ukupan_broj_u_srbiji_sa_poginulim_preko_noci)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA SMRTNIM ISHODOM PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom preko dana za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_poginulim_preko_dana = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa poginulim') & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_ns_sa_poginulim_preko_dana) 
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom preko noci za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_poginulim_preko_noci = count_ukupan_broj_u_ns_sa_poginulim - count_ukupan_broj_u_ns_sa_poginulim_preko_dana
print(count_ukupan_broj_u_ns_sa_poginulim_preko_noci) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA POVREDAMA PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama preko dana za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_povredama_preko_dana = len(df[(df["Vrsta"]=="Sa povredjenim") & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_srbiji_sa_povredama_preko_dana)
print("Ukupan broj saobracajnih nezgoda u Srbiji sa povredama preko noci za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_povredama_preko_noci = count_ukupan_broj_u_srbiji_sa_povredama - count_ukupan_broj_u_srbiji_sa_povredama_preko_dana
print(count_ukupan_broj_u_srbiji_sa_povredama_preko_noci)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA POVREDAMA PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama preko dana za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_povredama_preko_dana = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa povredjenim') & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_ns_sa_povredama_preko_dana) 
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa povredama preko noci za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_povredama_preko_noci = count_ukupan_broj_u_ns_sa_povredama - count_ukupan_broj_u_ns_sa_povredama_preko_dana
print(count_ukupan_broj_u_ns_sa_povredama_preko_noci) 

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U SRBIJI SA MATERIJALNOM STETOM PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom preko dana za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_dana = len(df[(df["Vrsta"]=="Sa mat.stetom") & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_dana)
print("Ukupan broj saobracajnih nezgoda u Srbiji sa materijalnom stetom preko noci za 2019. godinu je:")
count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_noci = count_ukupan_broj_u_srbiji_sa_mat_stetom - count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_dana
print(count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_noci)

#UKUPAN BROJ SAOBRACAJNIH NEZGODA U NOVOM SADU SA MATERIJALNOM STETOM PREKO DANA I PREKO NOCI
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom preko dana za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_mat_stetom_preko_dana = len(df[(df['Opština']=='NOVI SAD') & (df['Vrsta']=='Sa mat.stetom') & (df['Vreme'].between(pocetak_dana, kraj_dana))])
print(count_ukupan_broj_u_ns_sa_mat_stetom_preko_dana) 
print("Ukupan broj saobracajnih nezgoda u Novom Sadu sa materijalnom stetom preko noci za 2019. godinu je:")
count_ukupan_broj_u_ns_sa_mat_stetom_preko_noci = count_ukupan_broj_u_ns_sa_mat_stetom - count_ukupan_broj_u_ns_sa_mat_stetom_preko_dana
print(count_ukupan_broj_u_ns_sa_mat_stetom_preko_noci)
# Out:
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu preko dana je:
# 31382
# Ukupan broj saobracajnih nezgoda u Srbiji za 2019. godinu preko noci je:
# 4574
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu preko dana je:
# 2068
# Ukupan broj saobracajnih nezgoda u Novom Sadu za 2019. godinu preko noci je:
# 296
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom preko dana za 2019. godinu je:
# 402
# Ukupan broj saobracajnih nezgoda u Srbiji sa smrtnim ishodom preko noci za 2019. godinu je:
# 107
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom preko dana za 2019. godinu je:
# 19
# Ukupan broj saobracajnih nezgoda u Novom Sadu sa smrtnim ishodom preko noci za 2019. godinu je:
# 2
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama preko dana za 2019. godinu je:
# 12284
# Ukupan broj saobracajnih nezgoda u Srbiji sa povredama preko noci za 2019. godinu je:
# 1516
# ...

# %%
d = {
    "Ukupan broj u SRB": count_ukupan_broj_u_srbiji,
    "Ukupan broj u SRB sa poginulim": count_ukupan_broj_u_srbiji_sa_poginulim,
    "Ukupan broj u SRB sa povredama": count_ukupan_broj_u_srbiji_sa_povredama,
    "Ukupan broj u SRB sa mat. stetom": count_ukupan_broj_u_srbiji_sa_mat_stetom,
    "Ukupan broj u NS": count_ukupan_broj_u_ns,
    "Ukupan broj u NS sa poginulim": count_ukupan_broj_u_ns_sa_poginulim,
    "Ukupan broj u NS sa povredama": count_ukupan_broj_u_ns_sa_povredama,
    "Ukupan broj u NS sa mat. stetom": count_ukupan_broj_u_ns_sa_mat_stetom,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB  Ukupan broj u SRB sa poginulim  \
# 0              35956                             509
#
#    Ukupan broj u SRB sa povredama  Ukupan broj u SRB sa mat. stetom  \
# 0                           13800                             21647
#
#    Ukupan broj u NS  Ukupan broj u NS sa poginulim  \
# 0              2364                             21
#
#    Ukupan broj u NS sa povredama  Ukupan broj u NS sa mat. stetom
# 0                           1127                             1216

# %%
d = {
    "Ukupan broj u SRB sa pesacima": count_ukupan_broj_u_srbiji_sa_pesacima,
    "Ukupan broj u SRB sa poginulim sa pesacima": count_ukupan_broj_u_srbiji_sa_pesacima_sa_poginulim,
    "Ukupan broj u SRB sa povredama sa pesacima": count_ukupan_broj_u_srbiji_sa_pesacima_sa_povredama,
    "Ukupan broj u SRB sa mat. stetom sa pesacima": count_ukupan_broj_u_srbiji_sa_pesacima_sa_mat_stetom,
    "Ukupan broj u NS sa pesacima": count_ukupan_broj_u_ns_sa_pesacima,
    "Ukupan broj u NS sa poginulim sa pesacima": count_ukupan_broj_u_ns_sa_pesacima_sa_poginulim,
    "Ukupan broj u NS sa povredama sa pesacima": count_ukupan_broj_u_ns_sa_pesacima_sa_povredama,
    "Ukupan broj u NS sa mat. stetom sa pesacima": count_ukupan_broj_u_ns_sa_pesacima_sa_mat_stetom,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB sa pesacima  Ukupan broj u SRB sa poginulim sa pesacima  \
# 0                           2842                                         127
#
#    Ukupan broj u SRB sa povredama sa pesacima  \
# 0                                        2669
#
#    Ukupan broj u SRB sa mat. stetom sa pesacima  Ukupan broj u NS sa pesacima  \
# 0                                            46                           204
#
#    Ukupan broj u NS sa poginulim sa pesacima  \
# 0                                          8
#
#    Ukupan broj u NS sa povredama sa pesacima  \
# 0                                        195
#
#    Ukupan broj u NS sa mat. stetom sa pesacima
# 0                                            1

# %%
d = {
    "Ukupan broj u SRB sa parkiranim vozilom": count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom,
    "Ukupan broj u SRB sa poginulim sa parkiranim vozilom": count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_poginulim,
    "Ukupan broj u SRB sa povredama sa parkiranim vozilom": count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_povredama,
    "Ukupan broj u SRB sa mat. stetom sa parkiranim vozilom": count_ukupan_broj_u_srbiji_sa_parkiranim_vozilom_sa_mat_stetom,
    "Ukupan broj u NS sa parkiranim vozilom": count_ukupan_broj_u_ns_sa_parkiranim_vozilom,
    "Ukupan broj u NS sa poginulim sa parkiranim vozilom": count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_poginulim,
    "Ukupan broj u NS sa povredama sa parkiranim vozilom": count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_povredama,
    "Ukupan broj u NS sa mat. stetom sa parkiranim vozilom": count_ukupan_broj_u_ns_sa_parkiranim_vozilom_sa_mat_stetom,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB sa parkiranim vozilom  \
# 0                                     5456
#
#    Ukupan broj u SRB sa poginulim sa parkiranim vozilom  \
# 0                                                 22
#
#    Ukupan broj u SRB sa povredama sa parkiranim vozilom  \
# 0                                                357
#
#    Ukupan broj u SRB sa mat. stetom sa parkiranim vozilom  \
# 0                                               5077
#
#    Ukupan broj u NS sa parkiranim vozilom  \
# 0                                     273
#
#    Ukupan broj u NS sa poginulim sa parkiranim vozilom  \
# 0                                                  1
#
#    Ukupan broj u NS sa povredama sa parkiranim vozilom  \
# 0                                                 13
#
#    Ukupan broj u NS sa mat. stetom sa parkiranim vozilom
# 0                                                259

# %%
d = {
    "Ukupan broj u SRB sa jednim vozilom": count_ukupan_broj_u_srbiji_sa_jednim_vozilom,
    "Ukupan broj u SRB sa poginulim sa jednim vozilom": count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_poginulim,
    "Ukupan broj u SRB sa povredama sa jednim vozilom": count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_povredama,
    "Ukupan broj u SRB sa mat. stetom sa jednim vozilom": count_ukupan_broj_u_srbiji_sa_jednim_vozilom_sa_mat_stetom,
    "Ukupan broj u NS sa jednim vozilom": count_ukupan_broj_u_ns_sa_jednim_vozilom,
    "Ukupan broj u NS sa poginulim sa jednim vozilom": count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_poginulim,
    "Ukupan broj u NS sa povredama sa jednim vozilom": count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_povredama,
    "Ukupan broj u NS sa mat. stetom sa jednim vozilom": count_ukupan_broj_u_ns_sa_jednim_vozilom_sa_mat_stetom,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB sa jednim vozilom  \
# 0                                 7555
#
#    Ukupan broj u SRB sa poginulim sa jednim vozilom  \
# 0                                               165
#
#    Ukupan broj u SRB sa povredama sa jednim vozilom  \
# 0                                              2602
#
#    Ukupan broj u SRB sa mat. stetom sa jednim vozilom  \
# 0                                               4788
#
#    Ukupan broj u NS sa jednim vozilom  \
# 0                                 381
#
#    Ukupan broj u NS sa poginulim sa jednim vozilom  \
# 0                                                1
#
#    Ukupan broj u NS sa povredama sa jednim vozilom  \
# 0                                               86
#
#    Ukupan broj u NS sa mat. stetom sa jednim vozilom
# 0                                                294

# %%
d = {
    "Ukupan broj u SRB sa dva vozila": count_ukupan_broj_u_srbiji_sa_dva_vozila,
    "Ukupan broj u SRB sa poginulim sa dva vozila": count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_poginulim,
    "Ukupan broj u SRB sa povredama sa dva vozila": count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_povredama,
    "Ukupan broj u SRB sa mat. stetom sa dva vozila": count_ukupan_broj_u_srbiji_sa_dva_vozila_sa_mat_stetom,
    "Ukupan broj u NS sa dva vozila": count_ukupan_broj_u_ns_sa_dva_vozila,
    "Ukupan broj u NS sa poginulim sa dva vozila": count_ukupan_broj_u_ns_sa_dva_vozila_sa_poginulim,
    "Ukupan broj u NS sa povredama sa dva vozila": count_ukupan_broj_u_ns_sa_dva_vozila_sa_povredama,
    "Ukupan broj u NS sa mat. stetom sa dva vozila": count_ukupan_broj_u_ns_sa_dva_vozila_sa_mat_stetom,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB sa dva vozila  \
# 0                            20103
#
#    Ukupan broj u SRB sa poginulim sa dva vozila  \
# 0                                           195
#
#    Ukupan broj u SRB sa povredama sa dva vozila  \
# 0                                          8172
#
#    Ukupan broj u SRB sa mat. stetom sa dva vozila  \
# 0                                           11736
#
#    Ukupan broj u NS sa dva vozila  \
# 0                            1506
#
#    Ukupan broj u NS sa poginulim sa dva vozila  \
# 0                                           11
#
#    Ukupan broj u NS sa povredama sa dva vozila  \
# 0                                          833
#
#    Ukupan broj u NS sa mat. stetom sa dva vozila
# 0                                            662

# %%
d = {
    "Ukupan broj u SRB za vikend": count_ukupan_broj_u_srbiji_vikend,
    "Ukupan broj u SRB sa poginulim za vikend": count_ukupan_broj_u_srbiji_sa_poginulim_vikend,
    "Ukupan broj u SRB sa povredama za vikend": count_ukupan_broj_u_srbiji_sa_povredama_vikend,
    "Ukupan broj u SRB sa mat. stetom za vikend": count_ukupan_broj_u_srbiji_sa_mat_stetom_vikend,
    "Ukupan broj u NS za vikend": count_ukupan_broj_u_ns_vikend,
    "Ukupan broj u NS sa poginulim za vikend": count_ukupan_broj_u_ns_sa_poginulim_vikend,
    "Ukupan broj u NS sa povredama za vikend": count_ukupan_broj_u_ns_sa_povredama_vikend,
    "Ukupan broj u NS sa mat. stetom za vikend": count_ukupan_broj_u_ns_sa_mat_stetom_vikend,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB za vikend  Ukupan broj u SRB sa poginulim za vikend  \
# 0                         9300                                      4489
#
#    Ukupan broj u SRB sa povredama za vikend  \
# 0                                      6350
#
#    Ukupan broj u SRB sa mat. stetom za vikend  Ukupan broj u NS za vikend  \
# 0                                        7285                        4735
#
#    Ukupan broj u NS sa poginulim za vikend  \
# 0                                     4413
#
#    Ukupan broj u NS sa povredama za vikend  \
# 0                                     4559
#
#    Ukupan broj u NS sa mat. stetom za vikend
# 0                                       4587

# %%
d = {
    "Ukupan broj u SRB tokom radnih dana": count_ukupan_broj_u_srbiji_radni_dan,
    "Ukupan broj u SRB sa poginulim tokom radnih dana": count_ukupan_broj_u_srbiji_sa_poginulim_radni_dan,
    "Ukupan broj u SRB sa povredama tokom radnih dana": count_ukupan_broj_u_srbiji_sa_povredama_radni_dan,
    "Ukupan broj u SRB sa mat. stetom tokom radnih dana": count_ukupan_broj_u_srbiji_sa_mat_stetom_radni_dan,
    "Ukupan broj u NS tokom radnih dana": count_ukupan_broj_u_ns_radni_dan,
    "Ukupan broj u NS sa poginulim tokom radnih dana": count_ukupan_broj_u_ns_sa_poginulim_radni_dan,
    "Ukupan broj u NS sa povredama tokom radnih dana": count_ukupan_broj_u_ns_sa_povredama_radni_dan,
    "Ukupan broj u NS sa mat. stetom tokom radnih dana": count_ukupan_broj_u_ns_sa_mat_stetom_radni_dan,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB tokom radnih dana  \
# 0                                26656
#
#    Ukupan broj u SRB sa poginulim tokom radnih dana  \
# 0                                              3980
#
#    Ukupan broj u SRB sa povredama tokom radnih dana  \
# 0                                              7450
#
#    Ukupan broj u SRB sa mat. stetom tokom radnih dana  \
# 0                                              14362
#
#    Ukupan broj u NS tokom radnih dana  \
# 0                                2371
#
#    Ukupan broj u NS sa poginulim tokom radnih dana  \
# 0                                             4392
#
#    Ukupan broj u NS sa povredama tokom radnih dana  \
# 0                                             3432
#
#    Ukupan broj u NS sa mat. stetom tokom radnih dana
# 0                                               3371

# %%
d = {
    "Ukupan broj u SRB preko dana": count_ukupan_broj_u_srbiji_preko_dana,
    "Ukupan broj u SRB sa poginulim preko dana": count_ukupan_broj_u_srbiji_sa_poginulim_preko_dana,
    "Ukupan broj u SRB sa povredama preko dana": count_ukupan_broj_u_srbiji_sa_povredama_preko_dana,
    "Ukupan broj u SRB sa mat. stetom preko dana": count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_dana,
    "Ukupan broj u NS preko dana": count_ukupan_broj_u_ns_preko_dana,
    "Ukupan broj u NS sa poginulim preko dana": count_ukupan_broj_u_ns_sa_poginulim_preko_dana,
    "Ukupan broj u NS sa povredama preko dana": count_ukupan_broj_u_ns_sa_povredama_preko_dana,
    "Ukupan broj u NS sa mat. stetom preko dana": count_ukupan_broj_u_ns_sa_mat_stetom_preko_dana,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB preko dana  Ukupan broj u SRB sa poginulim preko dana  \
# 0                         31382                                        402
#
#    Ukupan broj u SRB sa povredama preko dana  \
# 0                                      12284
#
#    Ukupan broj u SRB sa mat. stetom preko dana  Ukupan broj u NS preko dana  \
# 0                                        18696                         2068
#
#    Ukupan broj u NS sa poginulim preko dana  \
# 0                                        19
#
#    Ukupan broj u NS sa povredama preko dana  \
# 0                                      1022
#
#    Ukupan broj u NS sa mat. stetom preko dana
# 0                                        1027

# %%
d = {
    "Ukupan broj u SRB preko noci": count_ukupan_broj_u_srbiji_preko_noci,
    "Ukupan broj u SRB sa poginulim preko noci": count_ukupan_broj_u_srbiji_sa_poginulim_preko_noci,
    "Ukupan broj u SRB sa povredama preko noci": count_ukupan_broj_u_srbiji_sa_povredama_preko_noci,
    "Ukupan broj u SRB sa mat. stetom preko noci": count_ukupan_broj_u_srbiji_sa_mat_stetom_preko_noci,
    "Ukupan broj u NS preko noci": count_ukupan_broj_u_ns_preko_noci,
    "Ukupan broj u NS sa poginulim preko noci": count_ukupan_broj_u_ns_sa_poginulim_preko_noci,
    "Ukupan broj u NS sa povredama preko noci": count_ukupan_broj_u_ns_sa_povredama_preko_noci,
    "Ukupan broj u NS sa mat. stetom preko noci": count_ukupan_broj_u_ns_sa_mat_stetom_preko_noci,
}
df = pd.DataFrame(d, index=[0])
df
# Out:
#    Ukupan broj u SRB preko noci  Ukupan broj u SRB sa poginulim preko noci  \
# 0                          4574                                        107
#
#    Ukupan broj u SRB sa povredama preko noci  \
# 0                                       1516
#
#    Ukupan broj u SRB sa mat. stetom preko noci  Ukupan broj u NS preko noci  \
# 0                                         2951                          296
#
#    Ukupan broj u NS sa poginulim preko noci  \
# 0                                         2
#
#    Ukupan broj u NS sa povredama preko noci  \
# 0                                       105
#
#    Ukupan broj u NS sa mat. stetom preko noci
# 0                                         189
